# %%
# %run Functions_Background.ipynb


    
olympics = read_data('athlete_events.csv')
world_gdp = read_data('world_gdp.csv', skiprows = 3)
noc_country = read_data('noc_regions.csv')
world_population = read_data('world_pop.csv')
olympics_host = read_data('olym.csv',encoding="ISO-8859–1")

# %%
print(get_shape(olympics))
print(get_shape(world_gdp))
print(get_shape(noc_country))
print(get_shape(world_population))
print(get_shape(olympics_host))
# Out:
# (271116, 15)
# (219, 61)
# (230, 3)
# (217, 61)
# (51, 7)

# %%
get_info(olympics)
# Out:
# The Dataframe has 271116 rows and 15 columns
# Column Names - 'ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'

# %%
get_info(world_gdp)
# Out:
# The Dataframe has 219 rows and 61 columns
# Column Names - 'Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'

# %%
get_info(noc_country)
# Out:
# The Dataframe has 230 rows and 3 columns
# Column Names - 'NOC', 'region', 'notes'

# %%
get_info(world_population)
# Out:
# The Dataframe has 217 rows and 61 columns
# Column Names - 'Country', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'

# %%
get_info(olympics_host)
# Out:
# The Dataframe has 51 rows and 7 columns
# Column Names - 'Host City', 'Country', 'Summer (Olympiad)', 'Winter', 'Year', 'latitude', 'longitude'

# %%
get_missing_values(olympics)
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
 Merge_olympics,merge_olympics_countrycode,olympics_merge_gdp,olympics_new,world_gdp,world_population  = data_cleaning(olympics, noc_country,world_gdp , world_population, olympics_host)
# Out:
# Hello

# %%
mergedframe,medalTotal_gdp = correlation(Merge_olympics,merge_olympics_countrycode,olympics_merge_gdp,olympics_new)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
countries = ['United States', 'Germany', 'China']
best,medal_tally_agnostic = team_performance(mergedframe,countries)
best.head(10)
# Out:
#               Team                                          Event  \
# 0            China                        Diving Women's Platform
# 1            China                     Diving Women's Springboard
# 2            China                   Table Tennis Women's Singles
# 3            China                     Table Tennis Men's Singles
# 4            China                Weightlifting Men's Lightweight
# 5            China                        Badminton Men's Singles
# 6            China                       Diving Men's Springboard
# 7            China           Diving Women's Synchronized Platform
# 8            China                Gymnastics Men's Floor Exercise
# 9            China                       Judo Women's Heavyweight
# 400        Germany                             Luge Men's Singles
# 401        Germany             Equestrianism Mixed Dressage, Team
# 402        Germany                           Luge Women's Singles
# 403        Germany                 Alpine Skiing Women's Combined
# 404        Germany  Canoeing Men's Canadian Doubles, 1,000 metres
# 405        Germany  Canoeing Men's Canadian Singles, 1,000 metres
# 406        Germany     Canoeing Men's Kayak Doubles, 1,000 metres
# 407        Germany     Canoeing Women's Kayak Doubles, 500 metres
# 408        Germany              Equestrianism Mixed Jumping, Team
# 409        Germany                  Rowing Men's Quadruple Sculls
# 921  United States                      Athletics Men's Long Jump
# 922  United States             Athletics Men's 110 metres Hurdles
# 923  United States             Athletics Men's 400 metres Hurdles
# 924  United States                     Athletics Men's 400 metres
# 925  United States                     Athletics Men's 200 metres
# 926  United States           Athletics Men's 4 x 400 metres Relay
# 927  United States                       Athletics Men's Shot Put
# 928  United States           Athletics Men's 4 x 100 metres Relay
# 929  United States                     Athletics Men's Pole Vault
# 930  United States                    Basketball Men's Basketball
#
#      Gold_Medal_Count
# 0                   7
# 1                   7
# 2                   7
# 3                   5
# 4                   5
# 5                   4
# 6                   4
# 7                   4
# 8                   4
# 9                   4
# 400                 6
# 401                 5
# 402                 5
# 403                 4
# 404                 4
# 405                 4
# 406                 4
# 407                 4
# 408                 4
# 409                 4
# 921                19
# 922                17
# 923                17
# 924                16
# 925                15
# 926                15
# 927                15
# 928                14
# 929                14
# 930                14

# %%
year_host_team_medal = home_advantage(medal_tally_agnostic)
year_host_team_medal
# Out:
#     Year         Country           Team  Season Medal_Won_Prev_Year  \
# 0   1900          France         France  Summer                  -
# 1   1904   United States  United States  Summer                  45
# 2   1912          Sweden         Sweden  Summer                  24
# 3   1924          France         France  Summer                  -
# 4   1924          France         France  Winter                  -
# 5   1928     Netherlands    Netherlands  Summer                  10
# 6   1932   United States  United States  Summer                  56
# 7   1932   United States  United States  Winter                  56
# 8   1952          Norway         Norway  Winter                   6
# 9   1952         Finland        Finland  Summer                  22
# 10  1956           Italy          Italy  Winter                  22
# 11  1956          Sweden         Sweden  Summer                  37
# 12  1956       Australia      Australia  Summer                  11
# 13  1960   United States  United States  Winter                  79
# 14  1964           Japan          Japan  Summer                   0
# 15  1964         Austria        Austria  Winter                   6
# 16  1968          France         France  Winter                  22
# 17  1968          Mexico         Mexico  Summer                   1
# 18  1972    West Germany   West Germany  Summer                  30
# 19  1972           Japan          Japan  Winter                  25
# 20  1976         Austria        Austria  Winter                   8
# 21  1976          Canada         Canada  Summer                   6
# 22  1980   United States  United States  Winter                 103
# 23  1984   United States  United States  Summer                  12
# 24  1984      Yugoslavia     Yugoslavia  Winter                   0
# 25  1988          Canada         Canada  Winter                  48
# 26  1988     South Korea    South Korea  Summer                  19
# 27  1992           Spain          Spain  Summer                   4
# 28  1992          France         France  Winter                  18
# 29  1994          Norway         Norway  Winter                  -
# 30  1996   United States  United States  Summer                 118
# 31  1998           Japan          Japan  Winter                   5
# 32  2000       Australia      Australia  Summer                  40
# 33  2002   United States  United States  Winter                  11
# 34  2008           China          China  Summer                  -
# 35  2010          Canada         Canada  Winter                  -
# 36  2014          Russia         Russia  Winter                  13
# 37  2016          Brazil         Brazil  Summer                  15
#
#     Medal_Won_Host_Year Medal_Won_Next_Year
# 0                  66.0                   1
# 1                 193.0                  46
# 2                  57.0                  -
# 3                  39.0                  24
# 4                  39.0                  24
# 5                  22.0                   8
# 6                 114.0                  59
# 7                 114.0                  59
# 8                  18.0                   7
# 9                  30.0                  22
# 10                 24.0                   1
# 11                 27.0                   7
# 12                 33.0                   0
# 13                  9.0                  92
# 14                 29.0                  25
# 15                  9.0                  13
# 16                 24.0                  16
# 17                  9.0                   1
# 18                 41.0                  46
# 19                 32.0                  25
# 20                  6.0                   6
# 21                 14.0                   2
# 22                 12.0                 180
# 23                180.0                  99
# 24                 19.0                  15
# 25                 14.0                  24
# 26                 32.0                  27
# 27                 23.0                  17
# 28                 36.0                  36
# 29                 23.0                  22
# 30                 99.0                  90
# 31                 10.0                   2
# 32                 57.0                  -
# 33                 29.0                  -
# 34                 93.0                  84
# 35                 22.0                  23
# 36                 28.0                  -
# 37                 17.0                  -

# %%
player = top_10_countries_summer(noc_country,olympics)

# %%
top_10_countries_winter(player)

# %%
athletes_summer(olympics)

# %%
athletes_winter(olympics)

# %%
BMI_by_event_participants_male(olympics)

# %%
BMI_by_event_participants_female(olympics)

# %%
BMI_by_event_gold_medalists_male(olympics)

# %%
BMI_by_event_gold_medalists_female(olympics)

# %%
BMI_by_time_gold_medalists(olympics)

# %%
summer_olympics = participants(olympics)

# %%
sprint_100m = sprinter_Height(summer_olympics)
sprint_100m
# Out:
#     Year  Overall Participants Average  Gold Medalists  All Medalists
# 0   1896                    176.285714           183.0     173.333333
# 1   1900                    175.714286           167.0     176.000000
# 2   1904                    176.333333           167.0     174.500000
# 3   1906                    177.181818           167.0     171.000000
# 4   1908                    176.500000           170.0     174.000000
# 5   1912                    177.787879           182.0     177.666667
# 6   1920                    178.000000           172.0     175.000000
# 7   1924                    172.615385           183.0     175.333333
# 8   1928                    174.500000           170.0     177.000000
# 9   1932                    175.541667           170.0     176.333333
# 10  1936                    178.172414           178.0     178.000000
# 11  1948                    177.057143           178.0     181.000000
# 12  1952                    175.200000           173.0     179.333333
# 13  1956                    175.633333           186.0     179.666667
# 14  1960                    176.101695           182.0     183.666667
# 15  1964                    175.575342           183.0     176.666667
# 16  1968                    175.384615           183.0     179.666667
# 17  1972                    176.148148           183.0     183.000000
# 18  1976                    176.225806           187.0     181.666667
# 19  1980                    176.288136           183.0     178.666667
# 20  1984                    176.632911           188.0     181.000000
# 21  1988                    177.232323           188.0     185.000000
# 22  1992                    178.246753           189.0     181.333333
# 23  1996                    178.280000           183.0     179.666667
# 24  2000                    177.817204           176.0     178.000000
# 25  2004                    177.682927           186.0     185.666667
# 26  2008                    178.378378           196.0     186.333333
# 27  2012                    177.492958           196.0     187.333333
# 28  2016                    177.064103           196.0     186.000000

# %%
sprint_100m = sprinter_weight(summer_olympics)
sprint_100m
# Out:
#     Year  Overall Participants Average  Gold Medalists  All Medalists
# 0   1896                     70.857143            66.0      63.666667
# 1   1900                     67.571429            58.0      64.333333
# 2   1904                     68.833333            64.0      67.500000
# 3   1906                     70.090909            64.0      67.000000
# 4   1908                     69.368421            61.0      66.333333
# 5   1912                     69.200000            73.0      70.000000
# 6   1920                     71.076923            75.0      76.000000
# 7   1924                     67.195652            75.0      66.666667
# 8   1928                     67.360000            56.0      71.666667
# 9   1932                     70.117647            65.0      73.333333
# 10  1936                     72.571429            71.0      77.666667
# 11  1948                     69.457143            69.0      71.000000
# 12  1952                     68.933333            67.0      68.000000
# 13  1956                     69.733333            75.0      70.666667
# 14  1960                     70.186441            71.0      71.000000
# 15  1964                     70.273973            86.0      76.666667
# 16  1968                     70.630769            81.0      76.333333
# 17  1972                     69.666667            80.0      79.666667
# 18  1976                     71.354839            90.0      80.000000
# 19  1980                     69.864407            86.0      76.666667
# 20  1984                     70.607595            80.0      75.000000
# 21  1988                     72.292929            80.0      81.000000
# 22  1992                     74.052632            94.0      79.000000
# 23  1996                     74.260000            82.0      76.666667
# 24  2000                     73.771739            80.0      77.666667
# 25  2004                     74.475610            80.0      79.666667
# 26  2008                     77.000000            95.0      85.000000
# 27  2012                     74.084507            95.0      85.000000
# 28  2016                     74.423077            95.0      81.666667

# %%
sprint_100m = sprinter_age(summer_olympics)
sprint_100m
# Out:
#     Year  Overall Participants Average  Gold Medalists  All Medalists
# 0   1896                     23.000000            21.0      22.500000
# 1   1900                     21.833333            21.0      22.666667
# 2   1904                     22.909091            23.0      21.000000
# 3   1906                     23.928571            25.0      26.000000
# 4   1908                     22.530612            19.0      22.333333
# 5   1912                     22.492754            22.0      21.000000
# 6   1920                     23.036364            19.0      21.666667
# 7   1924                     23.185714            24.0      24.666667
# 8   1928                     22.476923            19.0      21.666667
# 9   1932                     23.074074            23.0      22.333333
# 10  1936                     23.761905            22.0      22.666667
# 11  1948                     23.425926            25.0      27.000000
# 12  1952                     24.180556            21.0      27.333333
# 13  1956                     23.236364            21.0      23.666667
# 14  1960                     22.779661            23.0      22.333333
# 15  1964                     23.802817            21.0      23.666667
# 16  1968                     24.460317            22.0      22.333333
# 17  1972                     23.595238            22.0      23.333333
# 18  1976                     23.412698            25.0      25.333333
# 19  1980                     23.868852            28.0      25.666667
# 20  1984                     23.126582            23.0      21.666667
# 21  1988                     23.940594            27.0      27.333333
# 22  1992                     24.432099            32.0      27.333333
# 23  1996                     24.914286            28.0      26.000000
# 24  2000                     24.587629            26.0      25.333333
# 25  2004                     25.000000            22.0      25.666667
# 26  2008                     24.625000            21.0      22.000000
# 27  2012                     24.364865            25.0      25.666667
# 28  2016                     25.416667            29.0      28.000000

# %%
sprint_100m = sprinter_bmi(summer_olympics)
sprint_100m

# %%
summary,rmse = medal_predictor(olympics,world_gdp,world_population,medalTotal_gdp)
summary
# Out:
# 4896144
# 639664
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Medal_Won_Corrected   R-squared:                       0.739
# Model:                             OLS   Adj. R-squared:                  0.738
# Method:                  Least Squares   F-statistic:                     641.4
# Date:                 Sun, 15 Dec 2019   Prob (F-statistic):          1.29e-262
# Time:                         21:42:16   Log-Likelihood:                -2869.1
# No. Observations:                  912   AIC:                             5748.
# Df Residuals:                      907   BIC:                             5772.
# Df Model:                            4
# Covariance Type:             nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          7.1373      2.527      2.825      0.005       2.179      12.096
# Log_GDP           -0.4928      0.142     -3.466      0.001      -0.772      -0.214
# Log_Population     0.1730      0.132      1.307      0.192      -0.087       0.433
# Total_Athletes     0.1087      0.003     38.280      0.000       0.103       0.114
# GDP_per_capita  2.337e-08   2.31e-06      0.010      0.992   -4.51e-06    4.55e-06
# ==============================================================================
# Omnibus:                      531.276   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14441.656
# Skew:                           2.133   Prob(JB):                         0.00
# Kurtosis:                      22.022   Cond. No.                     1.22e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
rmse
# Out:
# 5.624026279753384
