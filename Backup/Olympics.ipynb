# %%
import pandas as pd


print("Hello Folks!")
country = pd.read_csv("olympics.csv") # Country Details 
olympic_athletes = pd.read_csv("athlete_events.csv") # Olympics Dataset

country.head()
olympic_athletes.head()
athletes_country = pd.merge(olympic_athletes, country ,  how='left', left_on='NOC', right_on = 'code')

olympic_athletes.head()
# Out:
# Hello Folks!
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#Definition of Country Dataset

country.info()
#country.columns=['Nation', 'Population', 'Exists' , 'Country Code', 'First Appearance', ]
#print("Hello")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 33 columns):
# nation                 226 non-null object
# population             226 non-null int64
# exists                 226 non-null object
# code                   226 non-null object
# first_app              226 non-null int64
# t_medal                226 non-null float64
# s_medal                226 non-null float64
# w_medal                226 non-null float64
# apps                   226 non-null int64
# medal                  226 non-null int64
# gold                   226 non-null int64
# silver                 226 non-null int64
# bronze                 226 non-null int64
# so_apps                226 non-null int64
# so_medal               226 non-null int64
# so_gold                226 non-null int64
# so_silver              226 non-null int64
# so_bronze              226 non-null int64
# wo_apps                226 non-null int64
# wo_medal               226 non-null int64
# ...

# %%
olympic_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
athletes_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 48 columns):
# ID                     271116 non-null int64
# Name                   271116 non-null object
# Sex                    271116 non-null object
# Age                    261642 non-null float64
# Height                 210945 non-null float64
# Weight                 208241 non-null float64
# Team                   271116 non-null object
# NOC                    271116 non-null object
# Games                  271116 non-null object
# Year                   271116 non-null int64
# Season                 271116 non-null object
# City                   271116 non-null object
# Sport                  271116 non-null object
# Event                  271116 non-null object
# Medal                  39783 non-null object
# nation                 270693 non-null object
# population             270693 non-null float64
# exists                 270693 non-null object
# ...

# %%
#athletes_country.groupby(['Team'],axis=1)

athletes.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f29d6fb818ae> in <module>
#       1 #athletes_country.groupby(['Team'],axis=1)
#       2
# ----> 3 athletes.head()
#
# NameError: name 'athletes' is not defined

# %%
athletes_country.groupby(['Team','Year','Event','Medal'])['Name'].value_counts()
#print(x)

#athletes_country.describe()

# %%
athletes_country.groupby(['Team','Year','Event','Medal','Age'])['Name'].value_counts()
#print(x)
#

# %%
olympic_athletes.(['Team','Year','Event','Medal','Age','Height'])['Name'].value_counts()
#print(x)groupby
# Out:
# Team                          Year  Event                                          Medal   Age   Height  Name
# Afghanistan                   2008  Taekwondo Men's Flyweight                      Bronze  21.0  183.0   Rohullah Nikpai                                      1
#                               2012  Taekwondo Men's Featherweight                  Bronze  25.0  183.0   Rohullah Nikpai                                      1
# Algeria                       1992  Athletics Women's 1,500 metres                 Gold    24.0  158.0   Hassiba Boulmerka                                    1
#                                     Boxing Men's Featherweight                     Bronze  19.0  165.0   Hocine Soltani                                       1
#                               1996  Athletics Men's 1,500 metres                   Gold    26.0  175.0   Noureddine Morceli                                   1
# ...

# %%
athletes_country.groupby(['Event'])['Age','Height','Weight'].mean()

# %%
# athletes_country.drop
# df = olympic_athletes[olympic_athletes.columns.drop(list(athletes_country.filter(regex='Art')))]
# #print(df)
# df.drop(df.loc[df['Event'].str.startswith('Art')].index, inplace=True)
# pd.set_option('display.max_columns', None) 
# #pd.options.display.max_rows = 999
olympic_athletes.groupby(['Event'])['Age','Height','Weight'].mean().head(100)
#olympic_athletes.mean()
# Out:
#                                                           Age      Height  \
# Event
# Aeronautics Mixed Aeronautics                       26.000000         NaN
# Alpine Skiing Men's Combined                        24.100352  180.143939
# Alpine Skiing Men's Downhill                        24.083770  177.947984
# Alpine Skiing Men's Giant Slalom                    23.330452  176.820246
# Alpine Skiing Men's Slalom                          23.523323  177.275732
# Alpine Skiing Men's Super G                         24.536842  179.677895
# Alpine Skiing Women's Combined                      22.800554  168.669091
# Alpine Skiing Women's Downhill                      22.501412  167.234165
# Alpine Skiing Women's Giant Slalom                  22.015609  166.357527
# Alpine Skiing Women's Slalom                        22.033126  167.171429
# Alpine Skiing Women's Super G                       23.109453  167.975207
# Alpinism Mixed Alpinism                             38.812500         NaN
# ...

# %%
athletes_country.info()
