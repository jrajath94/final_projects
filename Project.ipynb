# %%
import pandas as pd


print("Hello Folks!")
olympic_athletes = pd.read_csv("athlete_events.csv") # Olympics Dataset

olympic_athletes.head()
olympic_athletes['Medal'] = olympic_athletes['Medal'].fillna('DNW')
# Out:
# Hello Folks!

# %%
olympic_athletes.info()

# Check Missing values
olympic_athletes.isnull().sum()
#olympic_athletes['BMI'] = olympic_athletes['Weight']/(olympic_athletes['Height']/100)**2
#olympic_athletes['BMI']

olympic_athletes['Medal'] = olympic_athletes['Medal'].fillna('DNW')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     271116 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
summer_olympic_athletes = olympic_athletes[(olympic_athletes.Season == 'Summer')]
# summer_olympic_athletes_gold = summer_olympic_athletes[(olympic_athletes.Medal == 'Gold')]

# summer_olympic_athletes_gold.groupby('Year')['Height'].mean()
# summer_olympic_athletes_gold.groupby('Year')['Weight'].mean()
# #Participation Analysis

import seaborn as sns

summer_games = summer_olympic_athletes.groupby(["Year"])["ID"].nunique().reset_index()
#olympic_athletes = olympic_athletes.groupby(["Year"])["ID"].nunique().reset_index()

fig = plt.figure(figsize=(15,10))
ax = sns.pointplot(x = summer_olympic_athletes["Year"] , y = summer_olympic_athletes["ID"],color="black",markers="h")
ax.set_facecolor("w")

plt.ylabel("count")
plt.title("Athletes over years for Summer Olympics",color="g")
#summer_olympic_athletes
# Out:
# Text(0.5, 1.0, 'Athletes over years for Summer Olympics')

# %%
#Handling NaN values for Medal

olympic_athletes['Medal'].fillna(value="No_Medal" , inplace=True )
olympic_athletes.isnull().sum()

olympic_athletes['BMI'] = olympic_athletes['Weight']/(olympic_athletes['Height']/100)**2
olympic_athletes['BMI']
# Out:
# 0         24.691358
# 1         20.761246
# 2               NaN
# 3               NaN
# 4         23.959094
# 5         23.959094
# 6         23.959094
# 7         23.959094
# 8         23.959094
# 9         23.959094
# 10        21.220009
# 11        21.220009
# 12        21.220009
# 13        21.220009
# 14        21.220009
# 15        21.220009
# 16        21.220009
# 17        21.220009
# 18        21.499597
# 19        21.499597
# 20        21.499597
# 21        21.499597
# 22        21.499597
# 23        21.499597
# 24        21.499597
# 25        21.499597
# 26              NaN
# 27              NaN
# 28        27.748873
# 29              NaN
#             ...
# 271086    21.705129
# 271087    22.395790
# 271088    22.395790
# 271089    25.770399
# 271090    25.770399
# 271091    22.250000
# 271092    23.849777
# 271093    23.849777
# 271094    23.849777
# 271095    23.849777
# 271096    23.849777
# 271097    23.849777
# 271098    23.849777
# 271099    21.545091
# ...

# %%
olympic_athletes_gold = olympic_athletes[(olympic_athletes.Medal == 'Gold')]
olympic_athletes_silver = olympic_athletes[(olympic_athletes.Medal == 'Silver')]
olympic_athletes_bronze = olympic_athletes[(olympic_athletes.Medal == 'Bronze')]
olympic_athletes_gold.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal        BMI
# 3        Tug-Of-War Men's Tug-Of-War  Gold        NaN
# ...

# %%
olympic_athletes_silver.head()
# Out:
#      ID                Name Sex   Age  Height  Weight         Team  NOC  \
# 63   20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway  NOR
# 67   20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway  NOR
# 86   25    Alf Lied Aanning   M  24.0     NaN     NaN       Norway  NOR
# 92   30    Pepijn Aardewijn   M  26.0   189.0    72.0  Netherlands  NED
# 106  38        Karl Jan Aas   M  20.0     NaN     NaN       Norway  NOR
#
#            Games  Year  Season         City          Sport  \
# 63   1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 67   1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 86   1920 Summer  1920  Summer    Antwerpen     Gymnastics
# 92   1996 Summer  1996  Summer      Atlanta         Rowing
# 106  1920 Summer  1920  Summer    Antwerpen     Gymnastics
#
#                                              Event   Medal        BMI
# 63                    Alpine Skiing Men's Downhill  Silver  27.440599
# ...

# %%
olympic_athletes_bronze.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight     Team  NOC  \
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland  FIN
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland  FIN
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 50  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 37  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  1948 Summer  1948  Summer     London  Gymnastics
# 50  1952 Summer  1952  Summer   Helsinki  Gymnastics
#
#                                      Event   Medal        BMI
# 37  Swimming Men's 200 metres Breaststroke  Bronze        NaN
# 38  Swimming Men's 400 metres Breaststroke  Bronze        NaN
# ...

# %%
# Out:
# /Users/rj/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Text(0.5, 1.0, 'Athletes over years for Summer Olympics')

# %%
import numpy as np
#olympic_athletes[(olympic_athletes.Name.str.startswith("Michael Fred"))].count()
olympic_athletes['BMI'] = olympic_athletes['Weight']/(olympic_athletes['Height']/100)**2
#olympic_athletes['BMI']

# , as_index=False).agg(
#                       {'c':['mean','std'],'b':'first', 'd':'first'})
#summer_olympic_athletes_gold.groupby(['Event','Year'])['BMI'].mean()
#summer_olympic_athletes_gold.groupby(['Event','Year'], as_index=False).agg({'BMI':['mean','std']})

def func(x):
    return x.std() / np.sqrt(len(x))

#summer_olympic_athletes_gold.groupby(['Event','Year']).agg(['Year',func])

# d = {'BMI': ['mean', 'std']}
# #res = df.groupby('ID').agg(d)

# summer_olympic_athletes_gold
# mean_summer_olympic_athletes_gold = summer_olympic_athletes_gold.groupby(['Event','Year']).agg(d)



# #mean_summer_olympic_athletes_gold = mean_summer_olympic_athletes_gold.rename({2: 'BMI_Mean'})
# mean_summer_olympic_athletes_gold

#np.std(mean_summer_olympic_athletes_gold['BMI_Mean'])

summer_olympic_athletes_gold
#rnm_cols = dict(size='Size', sum='Sum', mean='Mean', std='Std')
#summer_olympic_athletes_gold.set_index(['Event','Year']).stack().groupby(['Event','Year'])['BMI'].agg(rnm_cols.keys()).rename(columns=rnm_cols)
# Out:
#             ID                                       Name Sex   Age  Height  \
# 3            4                       Edgar Lindenau Aabye   M  34.0     NaN
# 42          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 44          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 48          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 79          21                  Ragnhild Margrethe Aamodt   F  27.0   163.0
# 117         42                        Thomas Valentin Aas   M  25.0     NaN
# 150         56                                 Ren Abadie   M  21.0     NaN
# 172         72           Aleksey Aleksandrovich Abalmasov   M  28.0   180.0
# 173         73                                  Luc Abalo   M  23.0   182.0
# 174         73                                  Luc Abalo   M  27.0   182.0
# 178         76                 Jouan Patrice Abanda Etong   M  22.0   185.0
# ...

# %%
olympic_athletes['Medal'] = olympic_athletes['Medal'].fillna('DNW')

# %%
import matplotlib.pyplot as plt
#getting olympic Athletes with Height and Weight.
hw_olympic_athletes = olympic_athletes[(olympic_athletes['Height'].notnull()) & (olympic_athletes['Weight'].notnull())]

plt.figure(figsize=(15, 10))
plt.scatter(x="Height", y="Weight", data=hw_olympic_athletes)
plt.title('All Olympic Athletes from 1896-2016 Height vs Weight', fontsize=10)
plt.show()

# %%
Athletics_male=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sport"]=='Athletics')].loc[:,["BMI","Sport","Medal"]]    
Swimmers_male=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sport"]=='Swimming')].loc[:,["BMI","Sport","Medal"]]    
Wrestlers_male=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sport"]=='Wrestling')].loc[:,["BMI","Sport","Medal"]]    
Footballers_male=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sport"]=='Football')].loc[:,["BMI","Sport","Medal"]]    

f,ax=plt.subplots(1,4,figsize=(15,7))

Athletics_male.BMI.plot.hist(ax=ax[0],bins=30,edgecolor='black',color='red')

ax[0].set_title('BMI Distribution of Gold Athletics')

x1=list(range(15,50,5))

ax[0].set_xticks(x1)

Swimmers_male.BMI.plot.hist(ax=ax[1],bins=30,edgecolor='black',color='green')

ax[1].set_title('BMI Distribution of Gold Swimming')

x2=list(range(10,40,5))

ax[1].set_xticks(x2)




Wrestlers_male.BMI.plot.hist(ax=ax[2],bins=30,edgecolor='black',color='blue')

ax[2].set_title('BMI Distribution of Gold Wrestling')

x3=list(range(10,40,5))

ax[2].set_xticks(x3)


Footballers_male.BMI.plot.hist(ax=ax[3],bins=30,edgecolor='black',color='yellow')

ax[3].set_title('BMI Distribution of Gold Football')

x4=list(range(10,40,5))

ax[3].set_xticks(x4)


plt.show()

# %%
Athletics=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sex"]=='M') & (olympic_athletes["Sport"]=='Athletics')].loc[:,["BMI","Sport","Medal"]]    
Swimmers=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sex"]=='M') & (olympic_athletes["Sport"]=='Swimming')].loc[:,["BMI","Sport","Medal"]]    
Wrestlers=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sex"]=='M')  & (olympic_athletes["Sport"]=='Wrestling')].loc[:,["BMI","Sport","Medal"]]    
Footballers=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sex"]=='M') & (olympic_athletes["Sport"]=='Football')].loc[:,["BMI","Sport","Medal"]]    

f,ax=plt.subplots(1,4,figsize=(15,7))

Athletics.BMI.plot.hist(ax=ax[0],bins=30,edgecolor='black',color='red')
plt.title("Male")

ax[0].set_title('BMI Distribution of Athletics (Gold)')

x1=list(range(15,50,5))

ax[0].set_xticks(x1)

Swimmers.BMI.plot.hist(ax=ax[1],bins=30,edgecolor='black',color='green')

ax[1].set_title('BMI Distribution of Gold Swimming (Gold)')

x2=list(range(10,40,5))

ax[1].set_xticks(x2)




Wrestlers.BMI.plot.hist(ax=ax[2],bins=30,edgecolor='black',color='blue')

ax[2].set_title('BMI Distribution of Gold Wrestling (Gold)')

x3=list(range(10,40,5))

ax[2].set_xticks(x3)


Footballers.BMI.plot.hist(ax=ax[3],bins=30,edgecolor='black',color='yellow')

ax[3].set_title('BMI Distribution of Gold Football (Gold)')

x4=list(range(10,40,5))

ax[3].set_xticks(x4)


plt.show()

# %%
Athletics=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sex"]=='F') & (olympic_athletes["Sport"]=='Athletics')].loc[:,["BMI","Sport","Medal"]]    
Swimmers=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sex"]=='F') & (olympic_athletes["Sport"]=='Swimming')].loc[:,["BMI","Sport","Medal"]]    
Wrestlers=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sex"]=='F')  & (olympic_athletes["Sport"]=='Wrestling')].loc[:,["BMI","Sport","Medal"]]    
Footballers=olympic_athletes[(olympic_athletes["Medal"]=='Gold') & (olympic_athletes["Sex"]=='F') & (olympic_athletes["Sport"]=='Football')].loc[:,["BMI","Sport","Medal"]]    

f,ax=plt.subplots(1,4,figsize=(15,7))

Athletics.BMI.plot.hist(ax=ax[0],bins=30,edgecolor='black',color='red')

ax[0].set_title('BMI Distribution of Gold Athletics')

x1=list(range(15,50,5))

ax[0].set_xticks(x1)

Swimmers.BMI.plot.hist(ax=ax[1],bins=30,edgecolor='black',color='green')

ax[1].set_title('BMI Distribution of Gold Swimming')

x2=list(range(10,40,5))

ax[1].set_xticks(x2)




Wrestlers.BMI.plot.hist(ax=ax[2],bins=30,edgecolor='black',color='blue')

ax[2].set_title('BMI Distribution of Gold Wrestling')

x3=list(range(10,40,5))

ax[2].set_xticks(x3)


Footballers.BMI.plot.hist(ax=ax[3],bins=30,edgecolor='black',color='yellow')

ax[3].set_title('BMI Distribution of Gold Football')

x4=list(range(10,40,5))

ax[3].set_xticks(x4)


plt.show()

# %%
# Evolution Based on BMI


years = [1896,1900,1904,1908,1912,1916,1920,1924,1928,1932,1936,1948,1952]

Athletics_1896=olympic_athletes[(olympic_athletes["Year"].isin(years)) & (olympic_athletes["Sport"]=='Athletics')]

#Athletics_2016= olympic_athletes[(olympic_athletes["Year"]=='2016') & (olympic_athletes["Sport"]=='Athletics')].loc[:,["BMI","Sport","Medal"]]    
Athletics_2016=olympic_athletes[(olympic_athletes["Year"]==2016) & (olympic_athletes["Sport"]=='Athletics')]


Wrestlers_1896=olympic_athletes[(olympic_athletes["Year"].isin(years)) & (olympic_athletes["Sport"]=='Wrestling')]    
Wrestlers_2016=olympic_athletes[(olympic_athletes["Year"]==2016) & (olympic_athletes["Sport"]=='Wrestling')]

f,ax=plt.subplots(1,4,figsize=(15,7))

Athletics_1896.BMI.plot.hist(ax=ax[0],bins=30,edgecolor='black',color='purple')

ax[0].set_title('BMI Athletics Medals 1896-1952')

x1=list(range(15,50,5))

ax[0].set_xticks(x1)

Athletics_2016.BMI.plot.hist(ax=ax[1],bins=30,edgecolor='black',color='purple')

ax[1].set_title('BMI Athletics Medals 2016 ')

x2=list(range(10,40,5))

ax[1].set_xticks(x2)


Wrestlers_1896.BMI.plot.hist(ax=ax[2],bins=30,edgecolor='black',color='blue')

ax[2].set_title('BMI Wrestling 1896-1952 ')

x3=list(range(10,40,5))

ax[2].set_xticks(x3)


Wrestlers_2016.BMI.plot.hist(ax=ax[3],bins=30,edgecolor='black',color='blue')

ax[3].set_title('BMI Wrestling 2016')

x4=list(range(10,40,5))

ax[3].set_xticks(x4)


plt.show()

# %%
Athletics_1896=olympic_athletes[(olympic_athletes["Year"]==1896) & (olympic_athletes["Sport"]=='Athletics')].loc[:,["BMI","Sport","Medal"]]    
Athletics_1896
# Out:
#               BMI      Sport   Medal
# 7348          NaN  Athletics     DNW
# 18433         NaN  Athletics     DNW
# 22952         NaN  Athletics  Silver
# 22953         NaN  Athletics     DNW
# 32333   19.707964  Athletics    Gold
# 32334   19.707964  Athletics    Gold
# 42249         NaN  Athletics    Gold
# 42250         NaN  Athletics    Gold
# 42251         NaN  Athletics     DNW
# 44062   23.510204  Athletics  Silver
# 44063   23.510204  Athletics  Bronze
# 44064   23.510204  Athletics    Gold
# 47374   21.306818  Athletics     DNW
# 47375   21.306818  Athletics    Gold
# 48644         NaN  Athletics  Bronze
# 48857         NaN  Athletics  Silver
# 51139         NaN  Athletics     DNW
# 53221   30.971512  Athletics     DNW
# 56762   22.783309  Athletics     DNW
# 56763   22.783309  Athletics     DNW
# 56764   22.783309  Athletics     DNW
# 63068   28.859212  Athletics     DNW
# 68790         NaN  Athletics     DNW
# 68791         NaN  Athletics     DNW
# ...

# %%
# Few Details about the latest olympics   2016 - 

# Gold Medal Comparison from 1900 and 2016 

#Age Distribution

years = [1896,1900,1904,1908,1912,1916,1920,1924,1928]

summer_olympic_athletes_gold_1900 = summer_olympic_athletes_gold[summer_olympic_athletes_gold['Year'].isin(years)] 
summer_olympic_athletes_gold_2016 = summer_olympic_athletes_gold[summer_olympic_athletes_gold['Year'] ==2016] 

# summer_olympic_athletes_gold_1900.plot(kind='bar',x='Age',color='red')
# plt.show()
summer_olympic_athletes_gold_1900


f,ax=plt.subplots(1,2,figsize=(15,10))

summer_olympic_athletes_gold_1900.BMI.plot.hist(ax=ax[0],bins=30,edgecolor='black',color='purple')

ax[0].set_title('BMI Athletics Medals 1896-1928')

x1=list(range(15,50,5))

ax[0].set_xticks(x1)




summer_olympic_athletes_gold_2016.BMI.plot.hist(ax=ax[1],bins=30,edgecolor='black',color='purple')

ax[1].set_title('BMI Athletics Medals 2016')

x1=list(range(15,50,5))

ax[1].set_xticks(x1)

plt.show()

# %%
summer_olympic_athletes

# %%
#Participation Analysis

import seaborn as sns

summer_games = summer_olympic_athletes.groupby(["Year"])["ID"].nunique().reset_index()
#olympic_athletes = olympic_athletes.groupby(["Year"])["ID"].nunique().reset_index()

fig = plt.figure(figsize=(15,10))
plt.subplot(211)
ax = sns.pointplot(x = summer_olympic_athletes["Year"] , y = summer_olympic_athletes["ID"],color="white",markers="h")
plt.xticks(rotation = 60)
ax.set_facecolor("k")
#plt.grid(True,alpha=.2)
plt.ylabel("count")
plt.title("Athletes over years for Summer Olympics",color="g")
#summer_olympic_athletes
# Out:
# Text(0.5, 1.0, 'Athletes over years for Summer Olympics')

# %%
summer_olympic_athletes

# %%
sprinters = summer_olympic_athletes[summer_olympic_athletes['Event']=="Athletics Men's 100 metres"]
sprinters.groupby(['Year'])['Height'].mean()

sprinters_gold = summer_olympic_athletes[(summer_olympic_athletes['Medal']=='Gold') & (summer_olympic_athletes['Event']=="Athletics Men's 100 metres")]
sprinters_gold()

#Athletics Men's 100 metres
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-02cce850000c> in <module>
#       3
#       4 sprinters_gold = summer_olympic_athletes[(summer_olympic_athletes['Medal']=='Gold') & (summer_olympic_athletes['Event']=="Athletics Men's 100 metres")]
# ----> 5 sprinters_gold(['Year','Height'])
#       6
#       7 #Athletics Men's 100 metres
#
# TypeError: 'DataFrame' object is not callable

# %%
year_team_gdp = olympic_athletes.loc[:, ['Year', 'Team', 'GDP']].drop_duplicates()

medal_tally_gdp = medal_tally.merge(year_team_gdp,
                                   left_on = ['Year', 'Team'],
                                   right_on = ['Year', 'Team'],
                                   how = 'left')

row_mask_5 = medal_tally_gdp['Medal_Won_Corrected'] > 0
row_mask_6 = medal_tally_gdp['Team'].map(lambda x: x in top_countries)

correlation = medal_tally_gdp.loc[row_mask_5, ['GDP', 'Medal_Won_Corrected']].corr()['Medal_Won_Corrected'][0]

plot(medal_tally_gdp.loc[row_mask_5, 'GDP'], 
     medal_tally_gdp.loc[row_mask_5, 'Medal_Won_Corrected'] , 
     linestyle = 'none', 
     marker = 'o',
    alpha = 0.4)
xlabel('Country GDP')

ylabel('Number of Medals')
title('GDP versus medal tally')
text(np.nanpercentile(medal_tally_gdp['GDP'], 99.6), 
     max(medal_tally_gdp['Medal_Won_Corrected']) - 50,
     "Correlation = " + str(correlation))
